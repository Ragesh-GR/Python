# %%
# print function is used to display the text on screen 
print("Hello, Python world!")
# Out:
# Hello, Python world!

# %%
# Data types like int, float, char, string, bool

age = 20
weight = 75.3
name = "Ragu"

# %%
# input function is used to take information for user

name = input("Enter your name here: ")
print("Hello,", name)
# Out:
# Hello, rag

# %%
# Check the data types of variable by using type() function

x = 8
print(type(x))

name = 'ragu'
print(type(name))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# We can calculate numbers without variables and also display it

print("add: ",4+5)
print("div:", 4/5)
print("mul: ",4*5)
# Out:
# add:  9
# div: 0.8
# mul:  20

# %%
# Also we can change the data type of variable is called type casting

x = 8 # int data type
print(x)

x = float(x) # type change int to float
print(x)


age = input("Enter your age here: ") #age is str
print("your age: ", age)
print(type(age))

age = int(input("Enter your age here: ")) #now age is int
print("your age: ", age)
print(type(age))
# Out:
# 8
# 8.0
# your age:  32
# <class 'str'>
# your age:  32
# <class 'int'>
